# %% [markdown]
# # 🍵 Hello!
#
# **Hello!** My name is Jack Meng, check [here \[Note I don't really
# update this anymore\]](https://exoad.github.io/exoad/mds/Main.html) for
# more info about me! Or you can just continue reading. (Note: this is
# gonna be cringe :p)
#
#
# **<u>Simple Things About Me</u>**
#
# ## Things I do / About me
#
# -   **Competitive programmer** - currently doing USACO gold. Also do
#     things like CodeForces, GCJ, AtCoder, etc..
# -   **My Main (99%) proficient langs: C, Elixir, R, MatLab, TypeScript,
#     C++**
# -   **Currently learning: Lisp, Python, Java, M4, asm**
# -   **Currently in High School**
# -   **Main Orientation: Data Science, ML, Informatics**
# -   **What I have mainly created/contributed:
#     1. Yttrius - R + ASM-like OOP Lang
#     2. Darwin (forked) - C++ Machine Learning Framework
#     3. stdxx (Forked)- extension of the C++ stdlib
#     4. OpenC - Web Assembly with C (although kinda primitive)
#     5. Blender++ - A small implementation of integrating VScode with
#     Blender to form a lite game engine
#     6. ArctiC - (Not-public) A entirely rebuilt version of the original
#     Microsoft Visual Studio Code, removing all telemetry while also
#     adding important features like a simple ML-based coding analysis
#     (similar to a more broken GitHub Copilot), it also includes most of
#     it's GUI being rewritten in C in order to save time and move away
#     from electronJS
#     7. Discord Bot - Although I am less proud of these, I mainly work on
#     Discord Bots using my yAPI webASM & SDK protocol however I also
#     combined D++ a custom C++ Discord lib
#     Dont**
# -   **C is best lang!**
#
# ------------------------------------------------------------------------
#
# **<u>Languages & Frameworks</u>**
#
# ## Languages & Frameworks & Others
#
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/2e65fd64dbe65968d0f58fbe65e6edd331169d43.svg)](https://elixir-lang.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/06e39fbc265896dc6e529b339465ec18fb585046.svg)](https://www.oracle.com/java/technologies/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/f6bc89a3b9206d3b8199ca67c95a86fc20d56f06.svg)](https://en.wikipedia.org/wiki/C_(programming_language))
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/e72b7de54c8efd37f5a0b46c4d41a4f835396887.svg)](https://www.cplusplus.com/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/23863dcf8b4650101fef32328c5daca1ec05ae09.svg)](https://nodejs.org/en/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/ac043c1b378173c0317d06f9c172ff9d1a5f8c8b.svg)](https://clojure.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/896852eb65b6e9d344fea870b8f2e5f2642a2294.svg)](https://www.javascript.com/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/1e8bab22cdf6788444f9953a42fe55a22465d99a.svg)](https://html.spec.whatwg.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/12b72fda5d0a1c1a97e362633366828740eea78c.svg)](https://gradle.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/5c696792475902e0b8ffae2c510610dd2eb1cb12.svg)](https://maven.apache.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/f8c59a7bb5bac5bff30c2c988a002e67582e8c3c.svg)](https://www.rust-lang.org/)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/843dc02e5392ca72b0a053acb55507c6c01d94b3.svg)](https://crystal-lang.org/)
#
# ------------------------------------------------------------------------
#
# **<u>System Environment</u>**
#
# ## My System Environment
#
# -   **OS:** Manjaro, Arch
# -   **WM:** i3, BSPWM, PLASMA
# -   **Terminal/Shell:** Kitty, Alacritty
# -   **Code Environment:
#     [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/029449b55b6dcb0a71780a2846f6d885e0682e34.svg)](https://code.visualstudio.com/)
#     [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/c7dbc2919ba2693b7a112c04ca15758df156882f.svg)](https://www.jetbrains.com/clion/)
#     [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/395946078d1e3a1aba5d184a85150e331afaee65.svg)](https://www.gnu.org/software/emacs/)**
#
# ------------------------------------------------------------------------
#
# **<u>Social Links</u>**
#
# ## Socials
#
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/9444fd1bfa2606ae97d93cd59c0618d17dc589bd.svg)](https://discord.gg/PbJQRT9zQ8)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/a3af200cdba5020dcdf3b971df78d9aab37432e6.svg)](http://exoad.github.io/exoad)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/65fda0dc40a85afade7f71eabded147d164578f9.svg)](https://www.reddit.com/user/Chunkyfungus123)
# [![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/aeb1ee5b89a5096e69ac9be77207587acaf17a66.svg)](https://www.cornell.edu/)
#
# I am also on some other social sites like: LinkedIn, arXiv, etc.
#
# ------------------------------------------------------------------------
#
# **<u>Some extra stuffs</u>**
#
# ## Stats
#
# ![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/131a574cb00afc96141ed9c741239007a7046f5d.svg)
# ![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/b13e9337ac8c26f27ee2b111dc3db7f7553b268a.svg)
# ![](attachment:2f2418aa1e744632a7bfcaa2a370c6a9/9edfafe635ff15f4a6b661ee7cad5b7430f56a7f.svg)
#
# ------------------------------------------------------------------------
#
# **<u>Profile Formats</u>**
#
# ## View my profile in other languages!
#
# [English](https://github.com/exoad/exoad/blob/main/README.md)
# [Japanese](https://github.com/exoad/exoad/blob/main/README_JP.md)
# [Chinese](https://github.com/exoad/exoad/blob/main/README_CH.md)
#
# ------------------------------------------------------------------------
#
# ## View my profile in other formats!
#
# Note: not all languages are supported for different file types. **ALL
# FILE FORMATS ARE INCOMPLETE AND NEEDS FURTHER REVISIONS**
#
# [MARKDOWN (html
# form)`.md`](https://github.com/exoad/exoad/blob/main/README.md)
# [OPENDOCUMENT
# `.odt`](https://github.com/exoad/exoad/blob/main/README.odt)
# [RICH TEXT FORMAT
# `.rtf`](https://github.com/exoad/exoad/blob/main/README.rtf)
#
# ------------------------------------------------------------------------
#
#
#
# Yeah pretty bad profile readme
